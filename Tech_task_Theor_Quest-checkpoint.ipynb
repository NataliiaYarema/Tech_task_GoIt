# %% [markdown]
# # Технічне завдання до вакансії Junior Data Analyst
# *Виконавець:* **Наталія Ярема**

# %% [markdown]
# ## 📘 Theoretical Questions

# %% [markdown]
# *1. Які основні етапи аналізу даних ви знаєте?*

# %% [markdown]
# ### Основні етапи аналізу даних:
# - **Збір даних**, необхідних для проведення аналізу. Збір даних може проводитись з різних джерел, таких як бази даних, опитування, веб-сторінки тощо
# - **Очищення даних** від помилок та аномальних значень.
# - **Візуалізація даних** – побудова графіків, діаграм та інших візуальних представлень даних для кращого розуміння їх структури та взаємозв'язків.
# - **Аналіз даних** – на цьому етапі застосовуються різні методи аналізу для виявлення корисної інформації, закономірностей та трендів у даних.
# - **Інтерпретація результатів** – після проведення аналізу необхідно інтерпретувати отримані результати та висновки, щоб вони були зрозумілі для користувачів і могли використовуватися для прийняття рішень.

# %% [markdown]
# *2. Які продуктові метрики ти знаєш?*

# %% [markdown]
# ### Абсолютні продуктові показники:
# - **Revenue** – загальний дохід продукту. Операційний дохід —  отриманий від основної діяльності компанії. Чистий дохід - з вирахуванням з доходу податків, зборів, знижок тощо.
# - **Installs** – кількість встановлень (якщо продуктом є мобільний застосунок).
# - **DAU, WAU, MAU** –  Daily / Weekly / Monthly Active Users - кількість унікальних користувачів, які були активними за день / тиждень / місяць.
# - **MRR** – Monthly Recurring Revenue, місячний повторюваний дохід. Cума revenue за календарний місяць з джерел, які повторюються з місяця в місяць.
#
# ### Відносні продуктові показники:
# - **Conversion Rate** –  відсоток користувачів, які виконують бажану дію. Загальнa кількість користувачів, які «конвертують» / загальний розмір аудиторії * 100.
# - **Stickiness** – показник утримання користувачів. Cпіввідношення DAU/WAU, DAU/MAU, WAU/MAU. Показник понад 20% зазвичай вважається стабільним.
# - **ARPU** – Average Revenue per User, середній дохід на одного користувача. ARPU = Revenue / Users
# - **ARPPU**  – Average Revenue per Paying User, середній дохід на одного платника. ARPPU = Revenue / Paid Users.
# - **User Lifetime** – середня тривалість життя користувача на продукті.
# - **LTV** – Lifetime Value, середній дохід з користувача за весь час його життя. LTV = Average Revenue per Paid User x LifeTime
# середній місячний чек клієнта, що платить нам (ARPPU) * середню тривалість взаємодії з клієнтом у місяцях (LT).
# - **URR** - User Retention Rate – показник утримання користувачів. URR = (Кількість активних користувачів за певний час / Загальна кількість активних користувачів у попередньому періоді) x 100.
# - **Churn Rate** – показник втрати користувачів за певний період. Churn Rate(June) = Churned Users(June) / Paid users(May).

# %% [markdown]
# *3. Що таке когортний аналіз?*

# %% [markdown]
# **Cohort analysis** (когортний аналіз) — це вивчення спільних характеристик користувачів протягом певного періоду. Ними можуть бути нові користувачі та існуючі користувачі та їх подальша поведінка.
# **Cohort** (Когорта) — це група користувачів, які мають спільну характеристику протягом певного періоду часу.
# Завданнями когортного аналізу, зокрема, є оцінка показників утримання (Retention, Churn) та доходу на користувача (ARPU, ARPPU, LTV).
# **Основні типи когорт**:
# - Acquisition Cohorts (Когорти залучення клієнтів) – розбивають користувачів за часом, коли вони вперше зареєструвалися у продукті. Для користувачів застосунку можна розбити когорти за днями, тижнями або місяцями, коли вони запустили застосунок.
# - Behavioral Cohorts (Поведінкові когорти) – розбивають користувачів за діями, які вони здійснюють (або не здійснюють) протягом визначеного періоду часу.
