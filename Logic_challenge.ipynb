# %% [markdown]
# # Технічне завдання до вакансії Junior Data Analyst
# *Виконавець:* **Наталія Ярема**

# %% [markdown]
# ## 🧠 Логічне завдання

# %% [markdown]
# Уявіть, що ви працюєте з продуктом - мобільною грою в жанрі “симулятор ферми”. Ви помітили, що останнім часом гравці стали швидко “кидати” гру — значно впав середній час, проведений в застосунку. Шлях користувача виглядає наступним чином:
# - після першого запуску застосунку користувач вводить інформацію про себе: своє імʼя та вік;
# - після заповнення інформації про себе користувач проходить коротке навчання;
# - після проходження навчання користувач починає ігровий процес, через 10 хвилин після початку самої гри йому пропонується придбати стартовий набір з внутрішньо-ігровою валютою, який коштує $14.99.

# %% [markdown]
# *Відштовхуючись від зазначеної інформації, згенеруйте гіпотези, які фактори могли повпливати на термін життя користувача у грі та опишіть, як би ви перевіряли ці гіпотези. Запропонуйте свої варіанти для покращення користувацького досвіду.*

# %% [markdown]
# ## Проблема
# Гравці швидко "кидають" мобільну гру — середній час у застосунку різко зменшився.

# %% [markdown]
# ### Етапи шляху користувача:
# Реєстрація (введення імені та віку)
# Проходження навчання
# Початок гри + пропозиція купити стартовий набір через 10 хвилин

# %% [markdown]
# ## Гіпотези, що могли призвести до скорочення часу в грі:
# 1. Пропозиція $14.99 занадто рано
# 2. Контент гри не враховує особливості певної вікової групи
# 3. Технічні проблеми або низька продуктивність

# %% [markdown]
# ## Шляхи перевірки гіпотез:
# 1. Зіставити retention у гравців, яким показали пропозицію, з тими, кому не показували (A/B тест), перевірити конверсію в покупку цієї пропозиції, перевірити, чи є кореляція між моментом показу пропозиції підписки і відтоком користувачів
# 2. Зробити сегментацію за віком, побудувати графік середнього часу в грі за віковими групами, проаналізувати churn rate за віком
# 3. Перевірити краш-репорти, час завантаження, затримки, проаналізувати funnel від запуску до виходу

# %% [markdown]
# ## Ідеї для покращення користувацького досвіду:
# 1. Відкласти або зменшити першу монетизаційну пропозицію
# 2. Знизити ціну першої покупки
# 3. Запропонувати покупку після досягнення певної події (напр., перше будівництво чи апгрейд)
# 4. Ввести пробний безкоштовний період 3 дні
# 5. Ввести Welcome Bonus / Daily Gift
# 6. Адаптивний геймплей на старті. Наприклад: дітям — більше візуальної взаємодії, дорослим — більше стратегії
